# %% [markdown]
# # 1. string.capitalize()

# %%
string = "python"
print(string.capitalize())
# Out:
# Python

# %% [markdown]
# # 2. string.casefold()

# %%
string = "Python"
print(string.casefold())
# Out:
# python

# %% [markdown]
# # 3. string.center()

# %%
string = "Python"
print(string.center(15,"-"))
# Out:
# -----Python----

# %% [markdown]
# # 4. string.count()

# %%
string = "Hello World"
print(string.count("d"))
print(string.count("l"))
# Out:
# 1
# 3

# %% [markdown]
# # 5. string.encode()

# %%
string = "Hello World"
print(string.encode())
# Out:
# b'Hello World'

# %% [markdown]
# # 6. string.endswith()

# %%
string = "Hello World"
print(string.endswith("d"))
print(string.endswith("a"))
# Out:
# True
# False

# %% [markdown]
# # 7. string.startswith()

# %%
string = "Hello World"
print(string.startswith("h"))
print(string.startswith("H"))
print(string.startswith("e"))
# Out:
# False
# True
# False

# %% [markdown]
# # 8. string.expandtabs()

# %%
string = "python\tis\ta\tbest\tlanguage!"
print(string.expandtabs())
print(string.expandtabs(2))
# Out:
# python  is      a       best    language!
# python  is  a best  language!

# %% [markdown]
# # 9. string.ljust()

# %%
string = "Python"
print(string.ljust(10,"#"))
# Out:
# Python####

# %% [markdown]
# # 10. string.rjust()

# %%
string = "Python"
print(string.rjust(9,"-"))
# Out:
# ---Python

# %% [markdown]
# # 11. string.zfill()

# %%
string = "Hello world"
print(string.zfill(40))
# Out:
# 00000000000000000000000000000Hello world

# %% [markdown]
# # 12. string.format()

# %%
string = "Abhishek"
print("Hello, {}".format(string))
# Out:
# Hello, Abhishek

# %% [markdown]
# # 13. string.format_map()

# %%
data = {"name": "sonu","age": 22}
print("Name: {name}, Age: {age}".format_map(data))
# Out:
# Name: sonu, Age: 22

# %% [markdown]
# # 14. string.find()

# %%
string = "Hello world"
print(string.find("l"))
# Out:
# 2

# %% [markdown]
# # 15. string.rfind()

# %%
a = "python is python"
print(a.rfind("python"))
# Out:
# 10

# %% [markdown]
# # 16. string.index()

# %%
a = "Hello World"
print(a.index("o"))
# Out:
# 4

# %% [markdown]
# # 17. string.rindex()

# %%
a = "Hello world"
print(a.rindex("l"))
# Out:
# 9

# %% [markdown]
# # 18. string.isalnum()

# %%
a = "Python2"
print(a.isalnum())
# Out:
# True

# %% [markdown]
# # 19. string.isalpha()

# %%
a = "Python2"
print(a.isalpha())
a = "Python"
print(a.isalpha())
# Out:
# False
# True

# %% [markdown]
# # 20. string.isdigit()

# %%
a = "Python"
print(a.isdigit())
a = "4526"
print(a.isdigit())
# Out:
# False
# True

# %% [markdown]
# # 21. string.isnumeric()

# %%
a = "8956789562146"
print(a.isnumeric())
# Out:
# True

# %% [markdown]
# # 22. string.islower()

# %%
a = "python"
print(a.islower())
a = "Python"
print(a.islower())
# Out:
# True
# False

# %% [markdown]
# # 23. string.isupper()

# %%
a = "PYTHON"
print(a.isupper())
a = "Python"
print(a.isupper())
# Out:
# True
# False

# %% [markdown]
# # 24. string.istitle()

# %%
a = "Python is a best language"
print(a.istitle())
a = "Python Is A Best Language"
print(a.istitle())
# Out:
# False
# True

# %% [markdown]
# # 25. string.isspace()

# %%
a = " "
print(a.isspace())
a = "Python"
print(a.isspace())
# Out:
# True
# False

# %% [markdown]
# # 26. string.isidentifier()

# %%
a = "Hello world"
print(a.isidentifier())
a = "Hello_world"
print(a.isidentifier())
# Out:
# False
# True

# %% [markdown]
# # 27. string.isprintable()

# %%
a = "Hello world"
print(a.isprintable())
a = "Hello\nworld"
print(a.isidentifier())
# Out:
# True
# False

# %% [markdown]
# # 28. string.isascii()

# %%
a = "Hello world"
print(a.isascii())
# Out:
# True

# %% [markdown]
# # 29. string.isdecimal()

# %%
a = "Hello world"
print(a.isdecimal())
a = "12354"
print(a.isdecimal())
# Out:
# False
# True

# %% [markdown]
# # 30. string.strip()

# %%
a = "Hello world"
print(a.strip())
a = "Hello world"
print(a.strip("H"))
# Out:
# Hello world
# ello world

# %% [markdown]
# # 31. string.lstrip()

# %%
a = "     Hello world"
print(a.lstrip())
a = "####Hello world"
print(a.lstrip("#"))
# Out:
# Hello world
# Hello world

# %% [markdown]
# # 31. string.rstrip()

# %%
a = "Hello world    "
print(a.rstrip())
a = "####Hello world####"
print(a.rstrip("#"))
# Out:
# Hello world
# ####Hello world

# %% [markdown]
# # 32. string.removeprefix()

# %%
a = "Hello world"
print(a.removeprefix("Hello"))
# Out:
#  world
# Hello world

# %% [markdown]
# # 33. string.removesuffix()

# %%
a = "Hello world"
print(a.removesuffix("world"))
# Out:
# Hello
# Hello world

# %% [markdown]
# # 34. string.replace()

# %%
a = "Hello world"
print(a.replace("world","deepak"))
# Out:
# Hello deepak

# %% [markdown]
# # 35. string.lower()

# %%
a = "HELLO WORLD"
print(a.lower())
# Out:
# hello world

# %% [markdown]
# # 36. string.upper()

# %%
a = "hello world"
print(a.upper())
# Out:
# HELLO WORLD

# %% [markdown]
# # 37. string.title()

# %%
a = "HELLO WORLD"
print(a.title())
# Out:
# Hello World

# %% [markdown]
# # 38. string.swapcase()

# %%
a = "Hello world"
print(a.swapcase())
# Out:
# hELLO WORLD

# %% [markdown]
# # 39. string.partition()

# %%
a = "Hello-world"
print(a.partition("-"))
# Out:
# ('Hello', '-', 'world')

# %% [markdown]
# # 40. string.rpartition()

# %%
a = "Hello world"
print(a.rpartition("o"))
# Out:
# ('Hello w', 'o', 'rld')

# %% [markdown]
# # 41. string.translate()

# %%
table = string.maketrans("abc", "123")
text = "abc"
print(text.translate(table))
# Out:
# 123

# %% [markdown]
# # 42. string.split

# %%
string = "Hello world"
print(string.split())
# Out:
# ['Hello', 'world']

# %% [markdown]
# # 43. string.splitlines

# %%
a = "Hello World"
print(a.splitlines())
# Out:
# ['Hello World']

# %% [markdown]
# # 44. string.join()

# %%
a = ["Hello", "world"]
print("    ".join(a))
# Out:
# Hello    world
